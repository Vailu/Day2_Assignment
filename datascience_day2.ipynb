# %% [markdown]
# # Assignment-1

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
arr_1d= np.array([1,2,3,4,5,6])
print("1D Array: ")
print(arr_1d)
# Out:
# 1D Array:
# [1 2 3 4 5 6]

# %%
arr_2d= np.array([[1,2,3],[4,5,6]])
print("2D array :")
print(arr_2d)
# Out:
# 2D array :
# [[1 2 3]
#  [4 5 6]]

# %%
arr_1d=np.array([1,2,3,4])
arr_11d=np.array([2,3,4,5])
arr_sum=arr_1d+arr_11d
arr_multi=arr_1d*arr_11d
print("sum of the arrays:",arr_sum)
print("multiplication of the arrays :",arr_multi)
# Out:
# sum of the arrays: [3 5 7 9]
# multiplication of the arrays : [ 2  6 12 20]

# %%
arr = np.array([1, 2, 3, 4, 5, 6])
reshaped_arr = arr.reshape((2,3))
print("\nReshaped Array:")
print(reshaped_arr)
# Out:
# Reshaped Array:
# [[1 2 3]
#  [4 5 6]]

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
a1=df['Age']
a2=df['BMI']
c=np.add(a1,a2)
c
# Out:
# 0      83.6
# 1      57.6
# 2      55.3
# 3      49.1
# 4      76.1
#        ...
# 763    95.9
# 764    63.8
# 765    56.2
# 766    77.1
# 767    53.4
# Length: 768, dtype: float64

# %%
a1=df['Age']
a2=df['BMI']
c=np.power(a1,a2)
c
# Out:
# 0      1.217285e+57
# 1      4.679733e+39
# 2      1.174883e+35
# 3      1.426797e+37
# 4      2.805116e+65
#            ...
# 763    1.578716e+59
# 764    4.722658e+52
# 765    5.018534e+38
# 766    2.138679e+50
# 767    2.491875e+41
# Length: 768, dtype: float64

# %%
a1=df['Age']
a2=df['BMI']
c=np.concatenate((a1,a2))
c
# Out:
# array([50. , 31. , 32. , ..., 26.2, 30.1, 30.4])

# %%
df=pd.read_csv("student_marks.csv")
df
# Out:
#        name Gender  Maths  physics  chemistry  english  biology  economics  \
# 0       Sai      M     65       77         70       65       76         89
# 1    Lahari      F     66       78         66       67       78         98
# 2  Sai  Sri     F      65       76         65       76       67         87
# 3     Arjun      M     60       75         95       78       56         88
# 4    vaishu      F     70       79         97       76       45         89
# 5   Lakshmi      F     80       98         98       87       54         87
# 6      Sits      F     98       87         89       65       65         98
# 7     Eswar      M     90       88         88       67       55         77
# 8       Ram      M     88       98         87       66       88         67
# 9   Gayatri      F     87       88         89       68       87         65
#
#    history  civics
# 0       87      57
# 1       76      54
# 2       67      67
# 3       87      87
# 4       98      89
# 5       76      76
# ...

# %%
df['Total_Marks']=0
df
# Out:
#        name Gender  Maths  physics  chemistry  english  biology  economics  \
# 0       Sai      M     65       77         70       65       76         89
# 1    Lahari      F     66       78         66       67       78         98
# 2  Sai  Sri     F      65       76         65       76       67         87
# 3     Arjun      M     60       75         95       78       56         88
# 4    vaishu      F     70       79         97       76       45         89
# 5   Lakshmi      F     80       98         98       87       54         87
# 6      Sits      F     98       87         89       65       65         98
# 7     Eswar      M     90       88         88       67       55         77
# 8       Ram      M     88       98         87       66       88         67
# 9   Gayatri      F     87       88         89       68       87         65
#
#    history  civics  Total_Marks
# 0       87      57            0
# 1       76      54            0
# 2       67      67            0
# ...

# %%
df['Total_Marks']=df['Maths']+df['physics']+df['chemistry']+df['english']+df['biology']+df['economics']+df['history']+df['civics']
df
# Out:
#        name Gender  Maths  physics  chemistry  english  biology  economics  \
# 0       Sai      M     65       77         70       65       76         89
# 1    Lahari      F     66       78         66       67       78         98
# 2  Sai  Sri     F      65       76         65       76       67         87
# 3     Arjun      M     60       75         95       78       56         88
# 4    vaishu      F     70       79         97       76       45         89
# 5   Lakshmi      F     80       98         98       87       54         87
# 6      Sits      F     98       87         89       65       65         98
# 7     Eswar      M     90       88         88       67       55         77
# 8       Ram      M     88       98         87       66       88         67
# 9   Gayatri      F     87       88         89       68       87         65
#
#    history  civics  Total_Marks
# 0       87      57          586
# 1       76      54          583
# 2       67      67          570
# ...

# %%
df.drop(columns="Gender")
# Out:
#        name  Maths  physics  chemistry  english  biology  economics  history  \
# 0       Sai     65       77         70       65       76         89       87
# 1    Lahari     66       78         66       67       78         98       76
# 2  Sai  Sri     65       76         65       76       67         87       67
# 3     Arjun     60       75         95       78       56         88       87
# 4    vaishu     70       79         97       76       45         89       98
# 5   Lakshmi     80       98         98       87       54         87       76
# 6      Sits     98       87         89       65       65         98       88
# 7     Eswar     90       88         88       67       55         77       87
# 8       Ram     88       98         87       66       88         67       78
# 9   Gayatri     87       88         89       68       87         65       76
#
#    civics  Total_Marks
# 0      57          586
# 1      54          583
# 2      67          570
# 3      87          626
# ...

# %%
df[df['Total_Marks']>650]
# Out:
#       name Gender  Maths  physics  chemistry  english  biology  economics  \
# 5  Lakshmi      F     80       98         98       87       54         87
# 6     Sits      F     98       87         89       65       65         98
# 8      Ram      M     88       98         87       66       88         67
#
#    history  civics  Total_Marks
# 5       76      76          656
# 6       88      65          655
# 8       78      98          670

# %%
df.sort_values(by=['Total_Marks'])
# Out:
#        name Gender  Maths  physics  chemistry  english  biology  economics  \
# 2  Sai  Sri     F      65       76         65       76       67         87
# 1    Lahari      F     66       78         66       67       78         98
# 0       Sai      M     65       77         70       65       76         89
# 7     Eswar      M     90       88         88       67       55         77
# 3     Arjun      M     60       75         95       78       56         88
# 4    vaishu      F     70       79         97       76       45         89
# 9   Gayatri      F     87       88         89       68       87         65
# 6      Sits      F     98       87         89       65       65         98
# 5   Lakshmi      F     80       98         98       87       54         87
# 8       Ram      M     88       98         87       66       88         67
#
#    history  civics  Total_Marks
# 2       67      67          570
# 1       76      54          583
# 0       87      57          586
# ...

# %%
df_first_3=df.head(5)
print(df_first_3)
# Out:
#        name Gender  Maths  physics  chemistry  english  biology  economics  \
# 0       Sai      M     65       77         70       65       76         89
# 1    Lahari      F     66       78         66       67       78         98
# 2  Sai  Sri     F      65       76         65       76       67         87
# 3     Arjun      M     60       75         95       78       56         88
# 4    vaishu      F     70       79         97       76       45         89
#
#    history  civics  Total_Marks
# 0       87      57          586
# 1       76      54          583
# 2       67      67          570
# 3       87      87          626
# 4       98      89          643

# %%
df.isna().head()
# Out:
#     name  Gender  Maths  physics  chemistry  english  biology  economics  \
# 0  False   False  False    False      False    False    False      False
# 1  False   False  False    False      False    False    False      False
# 2  False   False  False    False      False    False    False      False
# 3  False   False  False    False      False    False    False      False
# 4  False   False  False    False      False    False    False      False
#
#    history  civics  Total_Marks
# 0    False   False        False
# 1    False   False        False
# 2    False   False        False
# 3    False   False        False
# 4    False   False        False

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('bmh')
df=pd.read_csv("carprices.csv")
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
x=df['Car Model']
y=df['Sell Price($)']

# %%
plt.xlabel('Car Model',fontsize=18)
plt.ylabel('Sell Price($)',fontsize=16)
plt.bar(x,y)
# Out:
# <BarContainer object of 13 artists>

# %%
plt.pie(y,labels=x,radius=1.2,autopct='%0.01f%%',shadow=True,explode=[.05,.2,.05,.2,.05,.2,.05,.2,.05,.2,.05,.2,.05])
# Out:
# ([<matplotlib.patches.Wedge at 0x184a81e8a30>,
# ...
#  [Text(1.3509049913944975, 0.22793793941648438, 'BMW X5'),
#   Text(1.2100025508309487, 0.9199422954634695, 'BMW X5'),
#   Text(0.4859917107775796, 1.280902828888859, 'BMW X5'),
#   Text(-0.377817189424512, 1.4722955448466735, 'BMW X5'),
#   Text(-1.085957536742368, 0.8352222628692608, 'BMW X5'),
#   Text(-1.513837468147175, 0.1367337560142034, 'Audi A5'),
#   Text(-1.2151150874799248, -0.632767986057018, 'Audi A5'),
#   Text(-0.8761028135946091, -1.2421126599514272, 'Audi A5'),
#   Text(-0.4356758238975535, -1.298878969138845, 'Audi A5'),
#   Text(-0.011997936474579935, -1.51995264713094, 'Mercedez Benz C class'),
#   Text(0.5108771613069957, -1.2711823339139456, 'Mercedez Benz C class'),
#   Text(1.0503277525894852, -1.098731819936203, 'Mercedez Benz C class'),
#   Text(1.3061717725725623, -0.41329807710011235, 'Mercedez Benz C class')],
#  [Text(0.7592677688859585, 0.12811110463554232, '5.3%'),
# ...

# %%
plt.xlabel('Car Model',fontsize=18)
plt.ylabel('Sell Price($)',fontsize=16)
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Assignment 2

# %%
emp=['syam','ram','sita','lahari','arjun']
age=[22,24,23,22,21]
salary=[25000,22000,15000,13000,16000]
table=(emp,age,salary)
print(table)
df=pd.DataFrame(table)
print(df)
# Out:
# (['syam', 'ram', 'sita', 'lahari', 'arjun'], [22, 24, 23, 22, 21], [25000, 22000, 15000, 13000, 16000])
#        0      1      2       3      4
# 0   syam    ram   sita  lahari  arjun
# 1     22     24     23      22     21
# 2  25000  22000  15000   13000  16000

# %%
print(table[1])
# Out:
# [22, 24, 23, 22, 21]

# %%
print(table[0])
# Out:
# ['syam', 'ram', 'sita', 'lahari', 'arjun']

# %%
emp={'Name':['syam','ram','sita','lahari','arjun'],'Age':[22,24,23,22,21],'salary':[25000,22000,15000,13000,16000]}
df=pd.DataFrame(emp)
df
# Out:
#      Name  Age  salary
# 0    syam   22   25000
# 1     ram   24   22000
# 2    sita   23   15000
# 3  lahari   22   13000
# 4   arjun   21   16000

# %%
print(df['Name'])
# Out:
# 0      syam
# 1       ram
# 2      sita
# 3    lahari
# 4     arjun
# Name: Name, dtype: object

# %%
print(df.loc[1])
# Out:
# Name        ram
# Age          24
# salary    22000
# Name: 1, dtype: object

# %%
filtered_df = df[df['salary']>15000]
print(filtered_df)
# Out:
#     Name  Age  salary
# 0   syam   22   25000
# 1    ram   24   22000
# 4  arjun   21   16000

# %%
sorted_df = df.sort_values('Name')
print(sorted_df)
# Out:
#      Name  Age  salary
# 4   arjun   21   16000
# 3  lahari   22   13000
# 1     ram   24   22000
# 2    sita   23   15000
# 0    syam   22   25000

# %%
df['Gender'] = ['Male','Male','Female','Female','Male']
print(df)
# Out:
#      Name  Age  salary  Gender
# 0    syam   22   25000    Male
# 1     ram   24   22000    Male
# 2    sita   23   15000  Female
# 3  lahari   22   13000  Female
# 4   arjun   21   16000    Male

# %%
sorted_df2 = df.sort_values('salary')
print(sorted_df2)
# Out:
#      Name  Age  salary  Gender
# 3  lahari   22   13000  Female
# 2    sita   23   15000  Female
# 4   arjun   21   16000    Male
# 1     ram   24   22000    Male
# 0    syam   22   25000    Male

# %%
sorted_df2['Gender']=['Female', 'Female', 'Male', 'Male','Male']
print(sorted_df2)
# Out:
#      Name  Age  salary  Gender
# 3  lahari   22   13000  Female
# 2    sita   23   15000  Female
# 4   arjun   21   16000    Male
# 1     ram   24   22000    Male
# 0    syam   22   25000    Male

# %%
sorted_df2.drop(['Gender'], axis=1)
# Out:
#      Name  Age  salary
# 3  lahari   22   13000
# 2    sita   23   15000
# 4   arjun   21   16000
# 1     ram   24   22000
# 0    syam   22   25000

# %%
grouped_df2=df.groupby('Gender').mean()
print(grouped_df2)
# Out:
#               Age   salary
# Gender
# Female  22.500000  14000.0
# Male    22.333333  21000.0

# %%
df_filled = df.fillna(0)
print(df_filled)
# Out:
#      Name  Age  salary  Gender
# 0    syam   22   25000    Male
# 1     ram   24   22000    Male
# 2    sita   23   15000  Female
# 3  lahari   22   13000  Female
# 4   arjun   21   16000    Male

# %%
import matplotlib.pyplot as plt
# Create a line plot
df_filled.plot(x='Name',y='Age',kind='line')
plt.show()

# %%
df_filled.plot(x='Name',y='Age',kind='box')
plt.show()

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('India_rainfall.csv')

# %%
a=data.head(10)
print(a)
# Out:
#                  SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5  628.7
# 5  ANDAMAN & NICOBAR ISLANDS  1906   36.6    0.0    0.0    0.0  556.1  733.3
# 6  ANDAMAN & NICOBAR ISLANDS  1907  110.7    0.0  113.3   21.6  616.3  305.2
# 7  ANDAMAN & NICOBAR ISLANDS  1908   20.9   85.1    0.0   29.0  562.0  693.6
# 8  ANDAMAN & NICOBAR ISLANDS  1910   26.6   22.7  206.3   89.3  224.5  472.7
# 9  ANDAMAN & NICOBAR ISLANDS  1911    0.0    8.4    0.0  122.5  327.3  649.0
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  10 non-null     object
#  1   YEAR         10 non-null     int64
#  2   JAN          10 non-null     float64
#  3   FEB          10 non-null     float64
#  4   MAR          10 non-null     float64
#  5   APR          10 non-null     float64
#  6   MAY          10 non-null     float64
#  7   JUN          10 non-null     float64
#  8   JUL          10 non-null     float64
#  9   AUG          10 non-null     float64
#  10  SEP          10 non-null     float64
#  11  OCT          10 non-null     float64
#  12  NOV          10 non-null     float64
#  13  DEC          10 non-null     float64
#  14  ANNUAL       10 non-null     float64
#  15  Jan-Feb      10 non-null     float64
#  16  Mar-May      10 non-null     float64
#  17  Jun-Sep      10 non-null     float64
# ...

# %%
a.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
a['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS'], dtype=object)

# %%
import seaborn as sns

# %%
sns.countplot(a['SUBDIVISION']).unique()
# Out:
# C:\Users\20jg1\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6016\3366771685.py in <module>
# ----> 1 sns.countplot(a['SUBDIVISION']).unique()
#
# AttributeError: 'AxesSubplot' object has no attribute 'unique'

# %%
data.isnull()
# Out:
#       SUBDIVISION   YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 0           False  False  False  False  False  False  False  False  False
# 1           False  False  False  False  False  False  False  False  False
# 2           False  False  False  False  False  False  False  False  False
# 3           False  False  False  False  False  False  False  False  False
# 4           False  False  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4111        False  False  False  False  False  False  False  False  False
# 4112        False  False  False  False  False  False  False  False  False
# 4113        False  False  False  False  False  False  False  False  False
# 4114        False  False  False  False  False  False  False  False  False
# 4115        False  False  False  False  False  False  False  False  False
#
#         AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %% [markdown]
# # Assignment-3

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('India_rainfall.csv')
data.head(5)
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
emp = {'Name': ['ram','syam','rahul','arjun',None,'sai','subbu','anvi','anvi','akhil'],
        'Age': [23,24,None,21,25,26,27,28,23,22],
        'Salary': [22000,20000,14000,13000,12000,15000,35000,22000,14000,25000]}
df = pd.DataFrame(emp)
print(df)
# Out:
#     Name   Age  Salary
# 0    ram  23.0   22000
# 1   syam  24.0   20000
# 2  rahul   NaN   14000
# 3  arjun  21.0   13000
# 4   None  25.0   12000
# 5    sai  26.0   15000
# 6  subbu  27.0   35000
# 7   anvi  28.0   22000
# 8   anvi  23.0   14000
# 9  akhil  22.0   25000

# %%
d=df['Age'].mean()
print(d)
# Out:
# 24.333333333333332

# %%
df['Age'].fillna(d)
# Out:
# 0    23.000000
# 1    24.000000
# 2    24.333333
# 3    21.000000
# 4    25.000000
# 5    26.000000
# 6    27.000000
# 7    28.000000
# 8    23.000000
# 9    22.000000
# Name: Age, dtype: float64

# %%
f=df['Salary'].mode()
print(f)
# Out:
# 0    14000
# 1    22000
# Name: Salary, dtype: int64

# %%
df['Name'].fillna('Hema')
# Out:
# 0      ram
# 1     syam
# 2    rahul
# 3    arjun
# 4     Hema
# 5      sai
# 6    subbu
# 7     anvi
# 8     anvi
# 9    akhil
# Name: Name, dtype: object

# %%
df[['Name','Age',"Salary"]].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
emp = {'Name': ['ram','syam','rahul','arjun','hema','sai','subbu','anvi','anvi','akhil'],
        'Age': [23,24,23,21,25,26,27,28,23,22],
        'Salary': [22000,20000,14000,13000,12000,15000,35000,22000,14000,25000]}
df = pd.DataFrame(emp)
print(df)
# Out:
#     Name  Age  Salary
# 0    ram   23   22000
# 1   syam   24   20000
# 2  rahul   23   14000
# 3  arjun   21   13000
# 4   hema   25   12000
# 5    sai   26   15000
# 6  subbu   27   35000
# 7   anvi   28   22000
# 8   anvi   23   14000
# 9  akhil   22   25000

# %%
df['Name'].unique()
# Out:
# array(['ram', 'syam', 'rahul', 'arjun', 'hema', 'sai', 'subbu', 'anvi',
#        'akhil'], dtype=object)

# %%
a=df[['Name','Age','Salary']].drop_duplicates()
print(a)
# Out:
#     Name  Age  Salary
# 0    ram   23   22000
# 1   syam   24   20000
# 2  rahul   23   14000
# 3  arjun   21   13000
# 4   hema   25   12000
# 5    sai   26   15000
# 6  subbu   27   35000
# 7   anvi   28   22000
# 8   anvi   23   14000
# 9  akhil   22   25000

# %%
import pandas as pd
data = pd.read_csv("africa_recession.csv")
data
# Out:
#            pop        emp  emp_to_pop_ratio        hc           ccon  \
# 0    28.849621   6.914298          0.239667  1.547767   99010.171880
# 1    45.728313  13.623806          0.297929  2.086037  316862.656300
# 2    33.262043  13.323813          0.400571  1.498783   29762.876950
# 3     8.025703   3.869000          0.482076  1.356151    6488.692871
# 4     1.061468   0.243000          0.228928  1.676330    7620.187500
# ..         ...        ...               ...       ...            ...
# 481  12.208407   6.215000          0.509075  1.837961   21853.750000
# 482  29.784193  15.389316          0.516694  1.467321   94663.101560
# 483  55.797787  25.301973          0.453458  1.689919  102405.859400
# 484  15.850567   5.277823          0.332974  1.579579   42087.269530
# 485   7.797694   3.468000          0.444747  1.790903   11765.336910
#
#                cda            cn        ck      ctfp     cwtfp  ...  \
# 0    131991.375000  4.265433e+05  0.009374  0.648979  0.626111  ...
# ...

# %%
q1=data['ccon'].quantile(0.25)
q3=data['ccon'].quantile(0.75)
iqr=q3-q1
print(iqr)
# Out:
# 48899.663330999996

# %%
lower_bound=q1-1.5*iqr
upper_bound=q3+1.5*iqr
print(lower_bound)
print(upper_bound)
# Out:
# -64232.28528
# 131366.368044

# %%
outliers=data[(data['ccon']>lower_bound)|(data['ccon']<upper_bound)]
print(outliers)
# Out:
#            pop        emp  emp_to_pop_ratio        hc           ccon  \
# 0    28.849621   6.914298          0.239667  1.547767   99010.171880
# 1    45.728313  13.623806          0.297929  2.086037  316862.656300
# 2    33.262043  13.323813          0.400571  1.498783   29762.876950
# 3     8.025703   3.869000          0.482076  1.356151    6488.692871
# 4     1.061468   0.243000          0.228928  1.676330    7620.187500
# ..         ...        ...               ...       ...            ...
# 481  12.208407   6.215000          0.509075  1.837961   21853.750000
# 482  29.784193  15.389316          0.516694  1.467321   94663.101560
# 483  55.797787  25.301973          0.453458  1.689919  102405.859400
# 484  15.850567   5.277823          0.332974  1.579579   42087.269530
# 485   7.797694   3.468000          0.444747  1.790903   11765.336910
#
#                cda            cn        ck      ctfp     cwtfp  ...  \
# 0    131991.375000  4.265433e+05  0.009374  0.648979  0.626111  ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data['ccon'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x184aab2a850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x184aab2adf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x184aab2a580>],
#  'medians': [<matplotlib.lines.Line2D at 0x184aab39400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x184aab39700>],
#  'means': []}

# %%
plt.boxplot(outliers['ccon'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x184aab91b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x184aaba2130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x184aab91880>],
#  'medians': [<matplotlib.lines.Line2D at 0x184aaba26d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x184aaba29a0>],
#  'means': []}

# %%
o=data[(data['ccon']<lower_bound)|(data['ccon']>upper_bound)]
print(o)
# Out:
#             pop        emp  emp_to_pop_ratio        hc         ccon  \
# 1     45.728313  13.623806          0.297929  2.086037  316862.6563
# 37    46.385006  13.191071          0.284382  2.124513  327957.1563
# 61    47.026173  13.843603          0.294381  2.163700  339416.7188
# 82   131.972534  40.408550          0.306189  1.547831  180237.1250
# 90    47.648727  13.527931          0.283910  2.203609  352717.0000
# 112   48.247395  13.649073          0.282898  2.244254  375248.9063
# 113  135.393616  43.250111          0.319440  1.578474  251140.8281
# 149  138.939484  44.426456          0.319754  1.609724  392136.0625
# 154   48.820587  14.254235          0.291972  2.285649  406479.2188
# 168   49.364582  15.090181          0.305688  2.327808  431853.8438
# 186  142.614090  45.836773          0.321404  1.641592  330836.9375
# 195   49.887180  14.892300          0.298520  2.370744  453303.0313
# 197  146.417023  47.357544          0.323443  1.674091  569466.0000
# ...

# %%
plt.boxplot(o['ccon'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x184aac0c070>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x184aac0c610>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x184aabfbd60>],
#  'medians': [<matplotlib.lines.Line2D at 0x184aac0cbb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x184aac0ce80>],
#  'means': []}

# %% [markdown]
# # Assignment-4

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
data=pd.read_csv("diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
numeric_features = data.select_dtypes(include=['float64', 'int64']).columns

# %%
scaler = MinMaxScaler()  # or scaler = StandardScaler() for standardization

# %%
data[numeric_features] = scaler.fit_transform(data[numeric_features])

# %%
data= data.head()
print(data)
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333      1.0
# 1                  0.116567  0.166667      0.0
# 2                  0.253629  0.183333      1.0
# 3                  0.038002  0.000000      0.0
# 4                  0.943638  0.200000      1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data['Glucose'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ee0c061bb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ee0c06f190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ee0c0618e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ee0c06f730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ee0c06fa00>],
#  'means': []}

# %%
plt.boxplot(data[['Glucose','BloodPressure','BMI']],labels=['Glucose','BloodPressure','BMI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ee0c0c94f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ee0c0c9a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ee0c0c91c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1ee0c0d5070>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1ee0c0d5340>,
# ...
#  'means': []}

# %%
scaler= MinMaxScaler()
scaled= scaler.fit_transform(data[['Glucose','BloodPressure','BMI']])
plt.boxplot(scaled,labels=['Glucose','BloodPressure','BMI'])
plt.show()

# %%
one_hot_encoded_data = pd.get_dummies(data, columns = ['Glucose','BloodPressure','BMI'])
print(one_hot_encoded_data)
# Out:
#    Pregnancies  SkinThickness   Insulin  DiabetesPedigreeFunction       Age  \
# 0     0.352941       0.353535  0.000000                  0.234415  0.483333
# 1     0.058824       0.292929  0.000000                  0.116567  0.166667
# 2     0.470588       0.000000  0.000000                  0.253629  0.183333
# 3     0.058824       0.232323  0.111111                  0.038002  0.000000
# 4     0.000000       0.353535  0.198582                  0.943638  0.200000
#
#    Outcome  Glucose_0.4271356783919598  Glucose_0.4472361809045226  \
# 0      1.0                           0                           0
# 1      0.0                           1                           0
# 2      1.0                           0                           0
# 3      0.0                           0                           1
# 4      1.0                           0                           0
#
#    Glucose_0.6884422110552764  Glucose_0.7437185929648241  \
# ...

# %%
emp = {'Name': ['syam','rahul','arjun','sai'],
        'Age': [23,24,23,21],
        'Salary': [22000,20000,14000,13000]}
df = pd.DataFrame(emp)
print(df)
# Out:
#     Name  Age  Salary
# 0   syam   23   22000
# 1  rahul   24   20000
# 2  arjun   23   14000
# 3    sai   21   13000

# %%
df['Salary']
# Out:
# 0    22000
# 1    20000
# 2    14000
# 3    13000
# Name: Salary, dtype: int64

# %%
df['place'] = ['Delhi','Goa','Shimla','Vizag']

# %%
print(df)
# Out:
#     Name  Age  Salary   place
# 0   syam   23   22000   Delhi
# 1  rahul   24   20000     Goa
# 2  arjun   23   14000  Shimla
# 3    sai   21   13000   Vizag

# %% [markdown]
# # Feature selection

# %%
x= df['place'].loc[1]
x
# Out:
# 'Goa'

# %%
#feature extraction
b

# %% [markdown]
# # Assignment-5

# %%
import matplotlib.pyplot as plt

years= ['2013','2014','2015','2016','2017']
values = [15,25,12,18,20]
plt.plot(years, values)
plt.xlabel('Time')
plt.ylabel('Numeric Variable')
plt.title('Trend of Numeric Variable Over Time')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
data=pd.read_csv('India_rainfall.csv')
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
a=data.head(10)
a
# Out:
#                  SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901   49.2   87.1   29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902    0.0  159.8   12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903   12.7  144.0    0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904    9.4   14.7    0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905    1.3    0.0    3.3   26.9  279.5  628.7
# 5  ANDAMAN & NICOBAR ISLANDS  1906   36.6    0.0    0.0    0.0  556.1  733.3
# 6  ANDAMAN & NICOBAR ISLANDS  1907  110.7    0.0  113.3   21.6  616.3  305.2
# 7  ANDAMAN & NICOBAR ISLANDS  1908   20.9   85.1    0.0   29.0  562.0  693.6
# 8  ANDAMAN & NICOBAR ISLANDS  1910   26.6   22.7  206.3   89.3  224.5  472.7
# 9  ANDAMAN & NICOBAR ISLANDS  1911    0.0    8.4    0.0  122.5  327.3  649.0
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
sns.lineplot(a['YEAR'],a['SUBDIVISION'])
# Out:
# C:\Users\20jg1\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='SUBDIVISION'>

# %%
sns.scatterplot(a['YEAR'],a['SUBDIVISION'])
# Out:
# C:\Users\20jg1\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YEAR', ylabel='SUBDIVISION'>

# %%
w=a.corr()
w
# Out:
#              YEAR       JAN       FEB       MAR       APR       MAY       JUN  \
# YEAR     1.000000  0.034457 -0.577848  0.408899  0.368844 -0.116272  0.180254
# JAN      0.034457  1.000000 -0.281957  0.462470 -0.281156  0.645596 -0.587290
# FEB     -0.577848 -0.281957  1.000000 -0.254252 -0.447861 -0.018590 -0.072253
# MAR      0.408899  0.462470 -0.254252  1.000000  0.070753 -0.114460 -0.568115
# APR      0.368844 -0.281156 -0.447861  0.070753  1.000000 -0.454207 -0.072623
# MAY     -0.116272  0.645596 -0.018590 -0.114460 -0.454207  1.000000  0.045121
# JUN      0.180254 -0.587290 -0.072253 -0.568115 -0.072623  0.045121  1.000000
# JUL     -0.299322  0.081363  0.310223 -0.225588 -0.010402 -0.180787 -0.327929
# AUG     -0.305488  0.010186  0.668351 -0.066140 -0.605808  0.484595  0.104519
# SEP     -0.014696 -0.517884  0.206068  0.095840  0.692507 -0.476049 -0.123031
# OCT     -0.059645  0.252355 -0.346516 -0.077939 -0.006680  0.240159  0.041104
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample correlation matrix
correlation_matrix = np.array([[1.0, 0.8, 0.2],
                              [0.8, 1.0, -0.4],
                              [0.2, -0.4, 1.0]])

correlation_matrix
# Out:
# array([[ 1. ,  0.8,  0.2],
#        [ 0.8,  1. , -0.4],
#        [ 0.2, -0.4,  1. ]])

# %%
sns.heatmap(correlation_matrix )
# Out:
# <AxesSubplot:>
